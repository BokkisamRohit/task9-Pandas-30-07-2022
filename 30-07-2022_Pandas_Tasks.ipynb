# %%
import pandas as pd

# %%
df=pd.read_excel("Agent_Login_Report (4).xls",header=None,names=df.loc[1].values.flatten().tolist())
df
# Out:
#                    SL No               Agent       Date   Login Time  \
# 0     Agent Login Report                 NaN        NaN          NaN
# 1                    NaN                 NaN        NaN          NaN
# 2                  SL No               Agent       Date   Login Time
# 3                      1  Shivananda Sonwane  30-Jul-22  03:35:29 PM
# 4                      2      Khushboo Priya  30-Jul-22  03:06:59 PM
# ...                  ...                 ...        ...          ...
# 998                  996        Manjunatha A  20-Jul-22  09:03:51 AM
# 999                  997            Bharath   20-Jul-22  09:00:49 AM
# 1000                 998      Khushboo Priya  20-Jul-22  08:59:20 AM
# 1001                 999        Nishtha Jain  20-Jul-22  08:43:55 AM
# 1002                1000              Tarun   01-Jul-22  01:52:47 AM
#
#       Logout Time   Duration
# 0             NaN        NaN
# 1             NaN        NaN
# 2     Logout Time   Duration
# 3     05:39:39 PM   02:04:10
# 4     03:07:16 PM   00:00:17
# ...           ...        ...
# 998   03:02:28 PM   05:58:37
# 999   03:01:32 PM   06:00:43
# 1000  02:26:55 PM   05:27:34
# 1001  02:00:33 PM   05:16:38
# 1002  12:01:07 PM  514:08:20
#
# [1003 rows x 6 columns]

# %%
df.drop(0,axis=0,inplace=True)

# %%
df
# Out:
#       SL No               Agent       Date   Login Time  Logout Time  \
# 1       NaN                 NaN        NaN          NaN          NaN
# 2     SL No               Agent       Date   Login Time  Logout Time
# 3         1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM
# 4         2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM
# 5         3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM
# ...     ...                 ...        ...          ...          ...
# 998     996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM
# 999     997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM
# 1000    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM
# 1001    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM
# 1002   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM
#
#        Duration
# 1           NaN
# 2      Duration
# 3      02:04:10
# 4      00:00:17
# 5      02:26:42
# ...         ...
# 998    05:58:37
# 999    06:00:43
# 1000   05:27:34
# 1001   05:16:38
# 1002  514:08:20
#
# [1002 rows x 6 columns]

# %%
df.drop(1,axis=0,inplace=True)

# %%
df
# Out:
#       SL No               Agent       Date   Login Time  Logout Time  \
# 2     SL No               Agent       Date   Login Time  Logout Time
# 3         1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM
# 4         2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM
# 5         3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM
# 6         4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM
# ...     ...                 ...        ...          ...          ...
# 998     996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM
# 999     997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM
# 1000    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM
# 1001    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM
# 1002   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM
#
#        Duration
# 2      Duration
# 3      02:04:10
# 4      00:00:17
# 5      02:26:42
# 6      00:45:06
# ...         ...
# 998    05:58:37
# 999    06:00:43
# 1000   05:27:34
# 1001   05:16:38
# 1002  514:08:20
#
# [1001 rows x 6 columns]

# %%
df.drop(2,axis=0,inplace=True)

# %%
df
# Out:
#      SL No               Agent       Date   Login Time  Logout Time   Duration
# 3        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM   02:04:10
# 4        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM   00:00:17
# 5        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM   02:26:42
# 6        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM   00:45:06
# 7        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM   01:08:36
# ...    ...                 ...        ...          ...          ...        ...
# 998    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM   05:58:37
# 999    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM   06:00:43
# 1000   998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM   05:27:34
# 1001   999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM   05:16:38
# 1002  1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  514:08:20
#
# [1000 rows x 6 columns]

# %%
df.dtypes
# Out:
# SL No          object
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# dtype: object

# %%
df1=pd.read_csv("AgentPerformance (1).xlsx - Agent Performance Report.csv",header=None,names=df1.loc[0].values.flatten().tolist())
df1
# Out:
#                          SL No        Date          Agent Name  Total Chats  \
# 0     Agent Performance Report         NaN                 NaN          NaN
# 1                        SL No        Date          Agent Name  Total Chats
# 2                            1  2022-07-30        Prerna Singh           11
# 3                            2  2022-07-30       Nandani Gupta           11
# 4                            3  2022-07-30          Ameya Jain           14
# ...                        ...         ...                 ...          ...
# 2157                      2156  2022-07-01   Sowmiya Sivakumar            0
# 2158                      2157  2022-07-01             Nitin M            0
# 2159                      2158  2022-07-01              Vivek             0
# 2160                      2159  2022-07-01       Ayushi Mishra            0
# 2161                      2160  2022-07-01  Chaitra K Hiremath            0
#
#       Average Response Time  Average Resolution Time  Average Rating  \
# 0                       NaN                      NaN             NaN
# 1     Average Response Time  Average Resolution Time  Average Rating
# 2                  00:00:38                 00:04:20            4.11
# 3                  00:01:15                 00:28:25            3.14
# 4                  00:00:30                 00:11:36            4.55
# ...                     ...                      ...             ...
# 2157               00:00:00                 00:00:00             0.0
# 2158               00:00:00                 00:00:00             0.0
# 2159               00:00:00                 00:00:00             0.0
# 2160               00:00:00                 00:00:00             0.0
# 2161               00:00:00                 00:00:00             0.0
#
#       Total Feedback
# 0                NaN
# 1     Total Feedback
# 2                  9
# 3                  7
# 4                 11
# ...              ...
# 2157               0
# 2158               0
# 2159               0
# 2160               0
# 2161               0
#
# [2162 rows x 8 columns]

# %%
df1.loc[0].values.flatten().tolist()
# Out:
# ['SL No',
#  'Date',
#  'Agent Name',
#  'Total Chats',
#  'Average Response Time',
#  'Average Resolution Time',
#  'Average Rating',
#  'Total Feedback']

# %%
df1.drop(0,axis=0,inplace=True)

# %%
df1
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 1     SL No        Date          Agent Name  Total Chats
# 2         1  2022-07-30        Prerna Singh           11
# 3         2  2022-07-30       Nandani Gupta           11
# 4         3  2022-07-30          Ameya Jain           14
# 5         4  2022-07-30       Mahesh Sarade           14
# ...     ...         ...                 ...          ...
# 2157   2156  2022-07-01   Sowmiya Sivakumar            0
# 2158   2157  2022-07-01             Nitin M            0
# 2159   2158  2022-07-01              Vivek             0
# 2160   2159  2022-07-01       Ayushi Mishra            0
# 2161   2160  2022-07-01  Chaitra K Hiremath            0
#
#       Average Response Time  Average Resolution Time  Average Rating  \
# 1     Average Response Time  Average Resolution Time  Average Rating
# 2                  00:00:38                 00:04:20            4.11
# 3                  00:01:15                 00:28:25            3.14
# 4                  00:00:30                 00:11:36            4.55
# 5                  00:01:04                 00:15:46            4.71
# ...                     ...                      ...             ...
# 2157               00:00:00                 00:00:00             0.0
# 2158               00:00:00                 00:00:00             0.0
# 2159               00:00:00                 00:00:00             0.0
# 2160               00:00:00                 00:00:00             0.0
# 2161               00:00:00                 00:00:00             0.0
#
#       Total Feedback
# 1     Total Feedback
# 2                  9
# 3                  7
# 4                 11
# 5                  7
# ...              ...
# 2157               0
# 2158               0
# 2159               0
# 2160               0
# 2161               0
#
# [2161 rows x 8 columns]

# %%
df1.drop(1,axis=0,inplace=True)

# %%
df1
# Out:
#      SL No        Date          Agent Name Total Chats Average Response Time  \
# 2        1  2022-07-30        Prerna Singh          11              00:00:38
# 3        2  2022-07-30       Nandani Gupta          11              00:01:15
# 4        3  2022-07-30          Ameya Jain          14              00:00:30
# 5        4  2022-07-30       Mahesh Sarade          14              00:01:04
# 6        5  2022-07-30              Swati           14              00:01:11
# ...    ...         ...                 ...         ...                   ...
# 2157  2156  2022-07-01   Sowmiya Sivakumar           0              00:00:00
# 2158  2157  2022-07-01             Nitin M           0              00:00:00
# 2159  2158  2022-07-01              Vivek            0              00:00:00
# 2160  2159  2022-07-01       Ayushi Mishra           0              00:00:00
# 2161  2160  2022-07-01  Chaitra K Hiremath           0              00:00:00
#
#      Average Resolution Time Average Rating Total Feedback
# 2                   00:04:20           4.11              9
# 3                   00:28:25           3.14              7
# 4                   00:11:36           4.55             11
# 5                   00:15:46           4.71              7
# 6                   00:16:33           3.67              6
# ...                      ...            ...            ...
# 2157                00:00:00            0.0              0
# 2158                00:00:00            0.0              0
# 2159                00:00:00            0.0              0
# 2160                00:00:00            0.0              0
# 2161                00:00:00            0.0              0
#
# [2160 rows x 8 columns]

# %% [markdown]
# 2) Total working days for each agents

# %%
date=pd.to_datetime(df1['Date'])

# %%
date
# Out:
# 2      2022-07-30
# 3      2022-07-30
# 4      2022-07-30
# 5      2022-07-30
# 6      2022-07-30
#           ...
# 2157   2022-07-01
# 2158   2022-07-01
# 2159   2022-07-01
# 2160   2022-07-01
# 2161   2022-07-01
# Name: Date, Length: 2160, dtype: datetime64[ns]

# %%
df1['converted_to_Date_Format']=pd.to_datetime(df1['Date'])
df1
# Out:
#      SL No        Date          Agent Name Total Chats Average Response Time  \
# 2        1  2022-07-30        Prerna Singh          11              00:00:38
# 3        2  2022-07-30       Nandani Gupta          11              00:01:15
# 4        3  2022-07-30          Ameya Jain          14              00:00:30
# 5        4  2022-07-30       Mahesh Sarade          14              00:01:04
# 6        5  2022-07-30              Swati           14              00:01:11
# ...    ...         ...                 ...         ...                   ...
# 2157  2156  2022-07-01   Sowmiya Sivakumar           0              00:00:00
# 2158  2157  2022-07-01             Nitin M           0              00:00:00
# 2159  2158  2022-07-01              Vivek            0              00:00:00
# 2160  2159  2022-07-01       Ayushi Mishra           0              00:00:00
# 2161  2160  2022-07-01  Chaitra K Hiremath           0              00:00:00
#
#      Average Resolution Time Average Rating Total Feedback  \
# 2                   00:04:20           4.11              9
# 3                   00:28:25           3.14              7
# 4                   00:11:36           4.55             11
# 5                   00:15:46           4.71              7
# 6                   00:16:33           3.67              6
# ...                      ...            ...            ...
# 2157                00:00:00            0.0              0
# 2158                00:00:00            0.0              0
# 2159                00:00:00            0.0              0
# 2160                00:00:00            0.0              0
# 2161                00:00:00            0.0              0
#
#      converted_to_Date_Format
# 2                  2022-07-30
# 3                  2022-07-30
# 4                  2022-07-30
# 5                  2022-07-30
# 6                  2022-07-30
# ...                       ...
# 2157               2022-07-01
# 2158               2022-07-01
# 2159               2022-07-01
# 2160               2022-07-01
# 2161               2022-07-01
#
# [2160 rows x 9 columns]

# %%
df1['days_of_a_date']=df1['converted_to_Date_Format'].dt.day
df1
# Out:
#      SL No        Date          Agent Name Total Chats Average Response Time  \
# 2        1  2022-07-30        Prerna Singh          11              00:00:38
# 3        2  2022-07-30       Nandani Gupta          11              00:01:15
# 4        3  2022-07-30          Ameya Jain          14              00:00:30
# 5        4  2022-07-30       Mahesh Sarade          14              00:01:04
# 6        5  2022-07-30              Swati           14              00:01:11
# ...    ...         ...                 ...         ...                   ...
# 2157  2156  2022-07-01   Sowmiya Sivakumar           0              00:00:00
# 2158  2157  2022-07-01             Nitin M           0              00:00:00
# 2159  2158  2022-07-01              Vivek            0              00:00:00
# 2160  2159  2022-07-01       Ayushi Mishra           0              00:00:00
# 2161  2160  2022-07-01  Chaitra K Hiremath           0              00:00:00
#
#      Average Resolution Time Average Rating Total Feedback  \
# 2                   00:04:20           4.11              9
# 3                   00:28:25           3.14              7
# 4                   00:11:36           4.55             11
# 5                   00:15:46           4.71              7
# 6                   00:16:33           3.67              6
# ...                      ...            ...            ...
# 2157                00:00:00            0.0              0
# 2158                00:00:00            0.0              0
# 2159                00:00:00            0.0              0
# 2160                00:00:00            0.0              0
# 2161                00:00:00            0.0              0
#
#      converted_to_Date_Format  days_of_a_date
# 2                  2022-07-30              30
# 3                  2022-07-30              30
# 4                  2022-07-30              30
# 5                  2022-07-30              30
# 6                  2022-07-30              30
# ...                       ...             ...
# 2157               2022-07-01               1
# 2158               2022-07-01               1
# 2159               2022-07-01               1
# 2160               2022-07-01               1
# 2161               2022-07-01               1
#
# [2160 rows x 10 columns]

# %%
#Solution for q2
'''
My understanding of the question is that how many no of working days an agent can work while excluding the two leaves 
'''
df1.groupby('Agent Name')['days_of_a_date'].count()-2
# Out:
# Agent Name
# Abhishek         28
# Aditya           28
# Aditya Shinde    28
# Aditya_iot       28
# Amersh           28
#                  ..
# Uday Mishra      28
# Vasanth P        28
# Vivek            28
# Wasim            28
# Zeeshan          28
# Name: days_of_a_date, Length: 70, dtype: int64

# %% [markdown]
# 3. Total query that you hvae taken

# %%
df1['Total Chats']=df1['Total Chats'].astype(int)

# %%
df1
# Out:
#      SL No        Date          Agent Name  Total Chats Average Response Time  \
# 2        1  2022-07-30        Prerna Singh           11              00:00:38
# 3        2  2022-07-30       Nandani Gupta           11              00:01:15
# 4        3  2022-07-30          Ameya Jain           14              00:00:30
# 5        4  2022-07-30       Mahesh Sarade           14              00:01:04
# 6        5  2022-07-30              Swati            14              00:01:11
# ...    ...         ...                 ...          ...                   ...
# 2157  2156  2022-07-01   Sowmiya Sivakumar            0              00:00:00
# 2158  2157  2022-07-01             Nitin M            0              00:00:00
# 2159  2158  2022-07-01              Vivek             0              00:00:00
# 2160  2159  2022-07-01       Ayushi Mishra            0              00:00:00
# 2161  2160  2022-07-01  Chaitra K Hiremath            0              00:00:00
#
#      Average Resolution Time Average Rating Total Feedback  \
# 2                   00:04:20           4.11              9
# 3                   00:28:25           3.14              7
# 4                   00:11:36           4.55             11
# 5                   00:15:46           4.71              7
# 6                   00:16:33           3.67              6
# ...                      ...            ...            ...
# 2157                00:00:00            0.0              0
# 2158                00:00:00            0.0              0
# 2159                00:00:00            0.0              0
# 2160                00:00:00            0.0              0
# 2161                00:00:00            0.0              0
#
#      converted_to_Date_Format  days_of_a_date
# 2                  2022-07-30              30
# 3                  2022-07-30              30
# 4                  2022-07-30              30
# 5                  2022-07-30              30
# 6                  2022-07-30              30
# ...                       ...             ...
# 2157               2022-07-01               1
# 2158               2022-07-01               1
# 2159               2022-07-01               1
# 2160               2022-07-01               1
# 2161               2022-07-01               1
#
# [2160 rows x 10 columns]

# %%
df1.dtypes
# Out:
# SL No                               object
# Date                                object
# Agent Name                          object
# Total Chats                          int32
# Average Response Time               object
# Average Resolution Time             object
# Average Rating                      object
# Total Feedback                      object
# converted_to_Date_Format    datetime64[ns]
# days_of_a_date                       int64
# dtype: object

# %%
#Solution for q3
df1.groupby('Agent Name')['Total Chats'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    277
# Aditya_iot       231
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             44
# Wasim            433
# Zeeshan          542
# Name: Total Chats, Length: 70, dtype: int32

# %% [markdown]
# 4. total Feedback that you have received

# %%
df1['Total Feedback']=df1['Total Feedback'].astype(int)
df1
# Out:
#      SL No        Date          Agent Name  Total Chats Average Response Time  \
# 2        1  2022-07-30        Prerna Singh           11              00:00:38
# 3        2  2022-07-30       Nandani Gupta           11              00:01:15
# 4        3  2022-07-30          Ameya Jain           14              00:00:30
# 5        4  2022-07-30       Mahesh Sarade           14              00:01:04
# 6        5  2022-07-30              Swati            14              00:01:11
# ...    ...         ...                 ...          ...                   ...
# 2157  2156  2022-07-01   Sowmiya Sivakumar            0              00:00:00
# 2158  2157  2022-07-01             Nitin M            0              00:00:00
# 2159  2158  2022-07-01              Vivek             0              00:00:00
# 2160  2159  2022-07-01       Ayushi Mishra            0              00:00:00
# 2161  2160  2022-07-01  Chaitra K Hiremath            0              00:00:00
#
#      Average Resolution Time Average Rating  Total Feedback  \
# 2                   00:04:20           4.11               9
# 3                   00:28:25           3.14               7
# 4                   00:11:36           4.55              11
# 5                   00:15:46           4.71               7
# 6                   00:16:33           3.67               6
# ...                      ...            ...             ...
# 2157                00:00:00            0.0               0
# 2158                00:00:00            0.0               0
# 2159                00:00:00            0.0               0
# 2160                00:00:00            0.0               0
# 2161                00:00:00            0.0               0
#
#      converted_to_Date_Format  days_of_a_date
# 2                  2022-07-30              30
# 3                  2022-07-30              30
# 4                  2022-07-30              30
# 5                  2022-07-30              30
# 6                  2022-07-30              30
# ...                       ...             ...
# 2157               2022-07-01               1
# 2158               2022-07-01               1
# 2159               2022-07-01               1
# 2160               2022-07-01               1
# 2161               2022-07-01               1
#
# [2160 rows x 10 columns]

# %%
df1.dtypes
# Out:
# SL No                               object
# Date                                object
# Agent Name                          object
# Total Chats                          int32
# Average Response Time               object
# Average Resolution Time             object
# Average Rating                      object
# Total Feedback                       int32
# converted_to_Date_Format    datetime64[ns]
# days_of_a_date                       int64
# dtype: object

# %%
#Solution for q4
df1.groupby('Agent Name')['Total Feedback'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    153
# Aditya_iot       131
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             20
# Wasim            284
# Zeeshan          335
# Name: Total Feedback, Length: 70, dtype: int32

# %% [markdown]
# 5. a agent name who have average rating between 3.5 to 4

# %%
df1['Average Rating']=df1['Average Rating'].astype(float)
df1
# Out:
#      SL No        Date          Agent Name  Total Chats Average Response Time  \
# 2        1  2022-07-30        Prerna Singh           11              00:00:38
# 3        2  2022-07-30       Nandani Gupta           11              00:01:15
# 4        3  2022-07-30          Ameya Jain           14              00:00:30
# 5        4  2022-07-30       Mahesh Sarade           14              00:01:04
# 6        5  2022-07-30              Swati            14              00:01:11
# ...    ...         ...                 ...          ...                   ...
# 2157  2156  2022-07-01   Sowmiya Sivakumar            0              00:00:00
# 2158  2157  2022-07-01             Nitin M            0              00:00:00
# 2159  2158  2022-07-01              Vivek             0              00:00:00
# 2160  2159  2022-07-01       Ayushi Mishra            0              00:00:00
# 2161  2160  2022-07-01  Chaitra K Hiremath            0              00:00:00
#
#      Average Resolution Time  Average Rating  Total Feedback  \
# 2                   00:04:20            4.11               9
# 3                   00:28:25            3.14               7
# 4                   00:11:36            4.55              11
# 5                   00:15:46            4.71               7
# 6                   00:16:33            3.67               6
# ...                      ...             ...             ...
# 2157                00:00:00            0.00               0
# 2158                00:00:00            0.00               0
# 2159                00:00:00            0.00               0
# 2160                00:00:00            0.00               0
# 2161                00:00:00            0.00               0
#
#      converted_to_Date_Format  days_of_a_date
# 2                  2022-07-30              30
# 3                  2022-07-30              30
# 4                  2022-07-30              30
# 5                  2022-07-30              30
# 6                  2022-07-30              30
# ...                       ...             ...
# 2157               2022-07-01               1
# 2158               2022-07-01               1
# 2159               2022-07-01               1
# 2160               2022-07-01               1
# 2161               2022-07-01               1
#
# [2160 rows x 10 columns]

# %%
df1.dtypes
# Out:
# SL No                               object
# Date                                object
# Agent Name                          object
# Total Chats                          int32
# Average Response Time               object
# Average Resolution Time             object
# Average Rating                     float64
# Total Feedback                       int32
# converted_to_Date_Format    datetime64[ns]
# days_of_a_date                       int64
# dtype: object

# %%
#Solution for q5
df1[(df1['Average Rating']>=3.5)&(df1['Average Rating']<=4)][['Agent Name','Average Rating']]
# Out:
#                Agent Name  Average Rating
# 6                  Swati             3.67
# 12           Manjunatha A            3.60
# 75    Boktiar Ahmed Bappy            4.00
# 78          Prateek _iot             3.75
# 80          Nandani Gupta            3.79
# ...                   ...             ...
# 1943       Jawala Prakash            3.80
# 2020        Sanjeev Kumar            4.00
# 2023        Aditya Shinde            3.54
# 2025     Deepranjan Gupta            3.71
# 2099        Sanjeev Kumar            4.00
#
# [114 rows x 2 columns]

# %% [markdown]
# 6 . Agent name who have rating lesss then 3.5

# %%
#Solution for q6
df1[(df1['Average Rating']<3.5)][['Agent Name','Average Rating']]
# Out:
#               Agent Name  Average Rating
# 3          Nandani Gupta            3.14
# 21      Hitesh Choudhary            0.00
# 22            Sanjeevan             0.00
# 23              Anirudh             0.00
# 24      Shiva Srivastava            0.00
# ...                  ...             ...
# 2157   Sowmiya Sivakumar            0.00
# 2158             Nitin M            0.00
# 2159              Vivek             0.00
# 2160       Ayushi Mishra            0.00
# 2161  Chaitra K Hiremath            0.00
#
# [1474 rows x 2 columns]

# %% [markdown]
# 7 . agent name who have rating more then 4.5

# %%
#Solution for q7
df1[(df1['Average Rating']>4.5)][['Agent Name','Average Rating']]
# Out:
#               Agent Name  Average Rating
# 4             Ameya Jain            4.55
# 5          Mahesh Sarade            4.71
# 7                Mukesh             4.62
# 8        Saikumarreddy N            5.00
# 9          Sanjeev Kumar            5.00
# ...                  ...             ...
# 2102      Shubham Sharma            5.00
# 2103       Jaydeep Dixit            4.77
# 2104  Shivananda Sonwane            4.86
# 2105      Khushboo Priya            4.61
# 2106     Hrisikesh Neogi            4.56
#
# [307 rows x 2 columns]

# %% [markdown]
# 8 . how many feedaback agents have received more then 4.5 average

# %%
res=df1.groupby('Agent Name')['Total Feedback'].mean()>4.5

# %%
#Solution for q8
l=[]
for i in res.iteritems():
    if(i[1]==True):
        l.append(i)
print(len(l))
# Out:
# 31

# %% [markdown]
# 11 . list of all agents name

# %%
df1['Agent Name'].unique()
# Out:
# array(['Prerna Singh', 'Nandani Gupta', 'Ameya Jain', 'Mahesh Sarade',
#        'Swati ', 'Mukesh ', 'Saikumarreddy N', 'Sanjeev Kumar',
#        'Shubham Sharma', 'Nishtha Jain', 'Manjunatha A', 'Khushboo Priya',
#        'Suraj S Bilgi', 'Harikrishnan Shaji', 'Hrisikesh Neogi',
#        'Shivan K', 'Sowmiya Sivakumar', 'Madhulika G', 'Mithun S',
#        'Hitesh Choudhary', 'Sanjeevan ', 'Anirudh ', 'Shiva Srivastava',
#        'Dibyanshu ', 'Ashish ', 'Uday Mishra', 'Aditya Shinde',
#        'Jayant Kumar', 'Aditya_iot ', 'Prabir Kumar Satapathy',
#        'Saurabh Shukla', 'Wasim ', 'Samprit ', 'Maitry ', 'Abhishek ',
#        'Rishav Dash', 'Aravind ', 'Tarun ', 'Muskan Garg', 'Ankit Sharma',
#        'Bharath ', 'Ashad Nasim', 'Vasanth P', 'Aditya ', 'Amersh ',
#        'Sandipan Saha', 'Ineuron Intelligence ', 'Mahak ', 'Mukesh Rao ',
#        'Zeeshan ', 'Anurag Tiwari', 'Ankitjha ', 'Saif Khan',
#        'Jaydeep Dixit', 'Sudhanshu Kumar', 'Maneesh ', 'Hyder Abbas',
#        'Rohan ', 'Vivek ', 'Nitin M', 'Shivan_S ', 'Spuri ',
#        'Ayushi Mishra', 'Chaitra K Hiremath', 'Prateek _iot ',
#        'Boktiar Ahmed Bappy', 'Shivananda Sonwane', 'Ishawant Kumar',
#        'Deepranjan Gupta', 'Jawala Prakash'], dtype=object)

# %% [markdown]
# 12 . percentage of chat on which they have received a feedback

# %%
df1['percentage_of_chat_that_got_feedback']=(df1['Total Feedback']/df1['Total Chats'])*100

# %%
df1['percentage_of_chat_that_got_feedback']
# Out:
# 2       81.818182
# 3       63.636364
# 4       78.571429
# 5       50.000000
# 6       42.857143
#           ...
# 2157          NaN
# 2158          NaN
# 2159          NaN
# 2160          NaN
# 2161          NaN
# Name: percentage_of_chat_that_got_feedback, Length: 2160, dtype: float64
